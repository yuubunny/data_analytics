# %% [markdown]
# <a href="https://colab.research.google.com/github/yuubunny/data_analytics/blob/main/AdvancedParsingMoviesData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
movies = pd.read_csv('sample_data/movies.csv', sep='|', header=None,
                     names=['Color', 'Director Name', 'Num of Critic Reviews', 'Duration',
                'Gross', 'Movie Title', 'Num of User Reviews',	'Country',
                'Content Rating', 'Budget', 'Title Year', 'IMDB Score', 'Genre'],
                     na_values='?', thousands=',', index_col='Movie Title')

# %%
movies.head()
# Out:
#                                                     Color      Director Name  \
# Movie Title
# Avatar                                              Color      James Cameron
# Pirates of the Caribbean: At World's End            Color     Gore Verbinski
# Spectre                                             Color         Sam Mendes
# The Dark Knight Rises                               Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens     ...    NaN        Doug Walker
#
#                                                     Num of Critic Reviews  \
# Movie Title
# Avatar                                                              723.0
# Pirates of the Caribbean: At World's End                            302.0
# Spectre                                                             602.0
# The Dark Knight Rises                                               813.0
# Star Wars: Episode VII - The Force Awakens     ...                    NaN
#
# ...

# %% [markdown]
# Lets find out the size of the dataset

# %%
movies.shape
# Out:
# (100, 12)

# %% [markdown]
# Lets inspect our data and find out which variables have missing data

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, Avatar  to The Hobbit: An Unexpected Journey
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Color                  99 non-null     object
#  1   Director Name          100 non-null    object
#  2   Num of Critic Reviews  99 non-null     float64
#  3   Duration               99 non-null     float64
#  4   Gross                  97 non-null     float64
#  5   Num of User Reviews    99 non-null     float64
#  6   Country                99 non-null     object
#  7   Content Rating         98 non-null     object
#  8   Budget                 96 non-null     float64
#  9   Title Year             99 non-null     float64
#  10  IMDB Score             100 non-null    float64
#  11  Genre                  100 non-null    object
# dtypes: float64(7), object(5)
# memory usage: 10.2+ KB

# %% [markdown]
# <a href="https://colab.research.google.com/github/yuubunny/data_analytics/blob/main/Copy_of_4_Pandas_DataFrames_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 2.0.3

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# Create an empty pandas DataFrame
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# you can also do this to create an empty dataframe
# pd.DataFrame(data=[None],
#             index=[None],
#             columns=[None])
# Out:
#       None
# None  None

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# create a dataframe with given marvel data
marvel_df = pd.DataFrame(marvel_data)

# %%
# or like this
# marvel_df = pd.DataFrame(data=marvel_data)
# marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
# add column names to the marvel_df
marvel_df.columns = ['Hero Name', 'Gender', 'First Appearance']

marvel_df
# Out:
#            Hero Name  Gender  First Appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
# or like this
# col_names = ['name', 'sex', 'first_appearance']

# marvel_df.columns = col_names
# marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# use the character names as the index
marvel_df.index = marvel_df['Hero Name']

marvel_df

# %%
# or like this
# marvel_df.index = marvel_df['name']
# marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# drop the name column since it's now the index

marvel_df = marvel_df.drop(columns=['Hero Name'])
marvel_df
# Out:
#                   Gender  First Appearance
# Hero Name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
# or like this

# marvel_df = marvel_df.drop(columns=['name'])
# marvel_df = marvel_df.drop(['name'], axis=1)
# marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# Drop Namor and Hank Pym rows
marvel_df.drop(['Namor', 'Hank Pym'], axis = 0)
# Out:
#                   Gender  First Appearance
# Hero Name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
# or like this
# marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
# marvel_df

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# show the first 5 elements on marvel_df
marvel_df.head()
# Out:
#                 Gender  First Appearance
# Hero Name
# Spider-Man        male              1962
# Captain America   male              1941
# Wolverine         male              1974
# Iron Man          male              1963
# Thor              male              1963

# %%
# or like this

#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
#marvel_df.iloc[:5,]
#marvel_df.head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# show the last 5 elements on marvel_df
#marvel_df.tail()

# or

marvel_df.iloc[-5:,]
# Out:
#                Gender  First Appearance
# Hero Name
# Hank Pym         male              1962
# Scarlet Witch  female              1964
# Wasp           female              1963
# Black Widow    female              1964
# Vision           male              1968

# %% [markdown]
# ## Notes
#
# ## loc is label indexing
# ## iloc indexes by position
#
#
# ## iloc example
# ### dataFrame.iloc[row,col]
# ### dataFrame.iloc[rowStart:rowEnd,ColStart:ColEnd]

# %%
#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
# marvel_df.iloc[-5:,]
#marvel_df.tail()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# just the sex of the first 5 elements
marvel_df['Gender'].head().to_frame()
# Out:
#                 Gender
# Hero Name
# Spider-Man        male
# Captain America   male
# Wolverine         male
# Iron Man          male
# Thor              male

# %%
# or like this

#marvel_df.iloc[:5,]['sex'].to_frame()
# marvel_df.iloc[:5,].sex.to_frame()
#marvel_df.head().sex.to_frame()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# of all middle elements on marvel_df
marvel_df['First Appearance'].iloc[1:-1,].to_frame()
# Out:
#                   First Appearance
# Hero Name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Namor                         1939
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Hank Pym                      1962
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
# or like this
# marvel_df.iloc[1:-1,].first_appearance.to_frame()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# first and last elements
print(marvel_df.head(1))
print(marvel_df.tail(1))

# this is better
marvel_df.iloc[[0,-1],]
# Out:
#            Gender  First Appearance
# Hero Name
# Spider-Man   male              1962
#           Gender  First Appearance
# Hero Name
# Vision      male              1968
#            Gender  First Appearance
# Hero Name
# Spider-Man   male              1962
# Vision       male              1968

# %%
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]

# this is better
# marvel_df.iloc[[0, -1],]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
# mod vision to 1964
marvel_df.loc['Vision','First Appearance'] = 1964
marvel_df
# Out:
#                   Gender  First Appearance
# Hero Name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1964

# %%
#marvel_df.loc['Vision', 'first_appearance'] = 1964

#marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# add a new column
marvel_df['years_since'] = (2024 - marvel_df['First Appearance'])

marvel_df
# Out:
#                   Gender  First Appearance  years_since
# Hero Name
# Spider-Man          male              1962           62
# Captain America     male              1941           83
# Wolverine           male              1974           50
# Iron Man            male              1963           61
# Thor                male              1963           61
# Thing               male              1961           63
# Mister Fantastic    male              1961           63
# Hulk                male              1962           62
# Beast               male              1963           61
# Invisible Woman   female              1961           63
# Storm             female              1975           49
# Namor               male              1939           85
# Hawkeye             male              1964           60
# Daredevil           male              1964           60
# Doctor Strange      male              1963           61
# Hank Pym            male              1962           62
# ...

# %%
# marvel_df['years_since'] = 2018 - marvel_df['first_appearance']

# marvel_df

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
marvel_df[marvel_df['Gender'] == 'female']


# Notes: Mask == boolean
# Out:
#                  Gender  First Appearance  years_since
# Hero Name
# Invisible Woman  female              1961           63
# Storm            female              1975           49
# Scarlet Witch    female              1964           60
# Wasp             female              1963           61
# Black Widow      female              1964           60

# %%
#mask = marvel_df['sex'] == 'female'

#mask

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# now select the males
marvel_df[marvel_df['Gender'] == 'male']
# Out:
#                  Gender  First Appearance  years_since
# Hero Name
# Spider-Man         male              1962           62
# Captain America    male              1941           83
# Wolverine          male              1974           50
# Iron Man           male              1963           61
# Thor               male              1963           61
# Thing              male              1961           63
# Mister Fantastic   male              1961           63
# Hulk               male              1962           62
# Beast              male              1963           61
# Namor              male              1939           85
# Hawkeye            male              1964           60
# Daredevil          male              1964           60
# Doctor Strange     male              1963           61
# Hank Pym           male              1962           62
# Vision             male              1964           60

# %%
#mask = marvel_df['sex'] == 'male'

#marvel_df[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# first appearances after 1970

marvel_df[marvel_df['First Appearance'] > 1970]
# Out:
#            Gender  First Appearance  years_since
# Hero Name
# Wolverine    male              1974           50
# Storm      female              1975           49

# %%
#mask = marvel_df['first_appearance'] > 1970

#marvel_df[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# female chars after 1970
marvel_df[(marvel_df['Gender'] == 'female') & (marvel_df['First Appearance'] > 1970)]
# Out:
#            Gender  First Appearance  years_since
# Hero Name
# Storm      female              1975           49

# %%
#mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)

#marvel_df[mask]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# basic stats
marvel_df.describe()
# Out:
#        First Appearance  years_since
# count         20.000000    20.000000
# mean        1961.650000    62.350000
# std            8.298859     8.298859
# min         1939.000000    49.000000
# 25%         1961.750000    60.000000
# 50%         1963.000000    61.000000
# 75%         1964.000000    62.250000
# max         1975.000000    85.000000

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# mean of first appearance
marvel_df['First Appearance'].mean()
# Out:
# 1961.65

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# min val of first appearance
marvel_df['First Appearance'].min()
# Out:
# 1939

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# characters with min vlaue of first appearance
marvel_df[marvel_df['First Appearance'] == 1939]
# Out:
#           Gender  First Appearance  years_since
# Hero Name
# Namor       male              1939           85

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# reset index names
marvel_df.reset_index()
# Out:
#            Hero Name  Gender  First Appearance  years_since
# 0         Spider-Man    male              1962           62
# 1    Captain America    male              1941           83
# 2          Wolverine    male              1974           50
# 3           Iron Man    male              1963           61
# 4               Thor    male              1963           61
# 5              Thing    male              1961           63
# 6   Mister Fantastic    male              1961           63
# 7               Hulk    male              1962           62
# 8              Beast    male              1963           61
# 9    Invisible Woman  female              1961           63
# 10             Storm  female              1975           49
# 11             Namor    male              1939           85
# 12           Hawkeye    male              1964           60
# 13         Daredevil    male              1964           60
# 14    Doctor Strange    male              1963           61
# ...

# %%
marvel_df = marvel_df.reset_index()

marvel_df
# Out:
#            Hero Name  Gender  First Appearance  years_since
# 0         Spider-Man    male              1962           62
# 1    Captain America    male              1941           83
# 2          Wolverine    male              1974           50
# 3           Iron Man    male              1963           61
# 4               Thor    male              1963           61
# 5              Thing    male              1961           63
# 6   Mister Fantastic    male              1961           63
# 7               Hulk    male              1962           62
# 8              Beast    male              1963           61
# 9    Invisible Woman  female              1961           63
# 10             Storm  female              1975           49
# 11             Namor    male              1939           85
# 12           Hawkeye    male              1964           60
# 13         Daredevil    male              1964           60
# 14    Doctor Strange    male              1963           61
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# plot first apearance

marvel_df.plot(y='First Appearance')
# Out:
# <Axes: >

# %%
# or like this
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df['First Appearance'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
marvel_df['First Appearance'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.hist(marvel_df['First Appearance'])
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 16.,  0.,  0.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
